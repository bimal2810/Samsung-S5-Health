# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import datetime
from dateutil.parser import parse

# %%
cols = ['sub_id', 'activity_code', 'timestamp', 'x', 'y','z']
all_data = pd.DataFrame()

# %% [markdown]
# # Reading Phone Accelerometer raw data

# %%
data_1600_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1600_accel_phone.txt', index_col = False, header = None, names = cols)
data_1601_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1601_accel_phone.txt', index_col = False, header = None, names = cols)
data_1602_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1602_accel_phone.txt', index_col = False, header = None, names = cols)
data_1603_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1603_accel_phone.txt', index_col = False, header = None, names = cols)
data_1604_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1604_accel_phone.txt', index_col = False, header = None, names = cols)
data_1605_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1605_accel_phone.txt', index_col = False, header = None, names = cols)
data_1606_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1606_accel_phone.txt', index_col = False, header = None, names = cols)
data_1607_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1607_accel_phone.txt', index_col = False, header = None, names = cols)
data_1608_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1608_accel_phone.txt', index_col = False, header = None, names = cols)
data_1609_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1609_accel_phone.txt', index_col = False, header = None, names = cols)
data_1610_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1610_accel_phone.txt', index_col = False, header = None, names = cols)
data_1611_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1611_accel_phone.txt', index_col = False, header = None, names = cols)
data_1612_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1612_accel_phone.txt', index_col = False, header = None, names = cols)
data_1613_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1613_accel_phone.txt', index_col = False, header = None, names = cols)
data_1614_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1614_accel_phone.txt', index_col = False, header = None, names = cols)
data_1615_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1615_accel_phone.txt', index_col = False, header = None, names = cols)
data_1616_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1616_accel_phone.txt', index_col = False, header = None, names = cols)
data_1617_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1617_accel_phone.txt', index_col = False, header = None, names = cols)
data_1618_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1618_accel_phone.txt', index_col = False, header = None, names = cols)
data_1619_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1619_accel_phone.txt', index_col = False, header = None, names = cols)
data_1620_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1620_accel_phone.txt', index_col = False, header = None, names = cols)
data_1621_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1621_accel_phone.txt', index_col = False, header = None, names = cols)
data_1622_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1622_accel_phone.txt', index_col = False, header = None, names = cols)
data_1623_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1623_accel_phone.txt', index_col = False, header = None, names = cols)
data_1624_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1624_accel_phone.txt', index_col = False, header = None, names = cols)
data_1625_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1625_accel_phone.txt', index_col = False, header = None, names = cols)
data_1626_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1626_accel_phone.txt', index_col = False, header = None, names = cols)
data_1627_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1627_accel_phone.txt', index_col = False, header = None, names = cols)
data_1628_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1628_accel_phone.txt', index_col = False, header = None, names = cols)
data_1629_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1629_accel_phone.txt', index_col = False, header = None, names = cols)
data_1630_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1630_accel_phone.txt', index_col = False, header = None, names = cols)
data_1631_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1631_accel_phone.txt', index_col = False, header = None, names = cols)
data_1632_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1632_accel_phone.txt', index_col = False, header = None, names = cols)
data_1633_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1633_accel_phone.txt', index_col = False, header = None, names = cols)
data_1634_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1634_accel_phone.txt', index_col = False, header = None, names = cols)
data_1635_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1635_accel_phone.txt', index_col = False, header = None, names = cols)
data_1636_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1636_accel_phone.txt', index_col = False, header = None, names = cols)
data_1637_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1637_accel_phone.txt', index_col = False, header = None, names = cols)
data_1638_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1638_accel_phone.txt', index_col = False, header = None, names = cols)
data_1639_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1639_accel_phone.txt', index_col = False, header = None, names = cols)
data_1640_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1640_accel_phone.txt', index_col = False, header = None, names = cols)
data_1641_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1641_accel_phone.txt', index_col = False, header = None, names = cols)
data_1642_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1642_accel_phone.txt', index_col = False, header = None, names = cols)
data_1643_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1643_accel_phone.txt', index_col = False, header = None, names = cols)
data_1644_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1644_accel_phone.txt', index_col = False, header = None, names = cols)
data_1645_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1645_accel_phone.txt', index_col = False, header = None, names = cols)
data_1646_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1646_accel_phone.txt', index_col = False, header = None, names = cols)
data_1647_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1647_accel_phone.txt', index_col = False, header = None, names = cols)
data_1648_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1648_accel_phone.txt', index_col = False, header = None, names = cols)
data_1649_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1649_accel_phone.txt', index_col = False, header = None, names = cols)
data_1650_accel_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\accel\\data_1650_accel_phone.txt', index_col = False, header = None, names = cols)

# %% [markdown]
# # Reading Phone Gyroscope data

# %%
data_1600_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1600_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1601_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1601_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1602_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1602_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1603_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1603_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1604_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1604_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1605_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1605_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1606_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1606_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1607_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1607_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1608_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1608_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1609_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1609_gyro_phone.txt', index_col = False, header = None, names = cols)

data_1610_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1610_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1611_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1611_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1612_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1612_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1613_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1613_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1614_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1614_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1615_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1615_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1616_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1616_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1617_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1617_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1618_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1618_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1619_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1619_gyro_phone.txt', index_col = False, header = None, names = cols)


data_1620_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1620_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1621_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1621_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1622_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1622_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1623_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1623_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1624_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1624_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1625_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1625_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1626_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1626_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1627_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1627_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1628_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1628_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1629_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1629_gyro_phone.txt', index_col = False, header = None, names = cols)

data_1630_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1630_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1631_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1631_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1632_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1632_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1633_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1633_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1634_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1634_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1635_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1635_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1636_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1636_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1637_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1637_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1638_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1638_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1639_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1639_gyro_phone.txt', index_col = False, header = None, names = cols)

data_1640_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1640_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1641_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1641_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1642_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1642_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1643_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1643_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1644_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1644_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1645_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1645_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1646_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1646_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1647_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1647_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1648_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1648_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1649_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1649_gyro_phone.txt', index_col = False, header = None, names = cols)
data_1650_gyro_phone = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\Phone and watch\\raw\\phone\\gyro\\data_1650_gyro_phone.txt', index_col = False, header = None, names = cols)

# %% [markdown]
# # Reading Watch Accelerometer data

# %%
data_1600_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1600_accel_watch.txt', index_col = False, header = None, names = cols)
data_1601_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1601_accel_watch.txt', index_col = False, header = None, names = cols)
data_1602_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1602_accel_watch.txt', index_col = False, header = None, names = cols)
data_1603_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1603_accel_watch.txt', index_col = False, header = None, names = cols)
data_1604_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1604_accel_watch.txt', index_col = False, header = None, names = cols)
data_1605_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1605_accel_watch.txt', index_col = False, header = None, names = cols)
data_1606_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1606_accel_watch.txt', index_col = False, header = None, names = cols)
data_1607_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1607_accel_watch.txt', index_col = False, header = None, names = cols)
data_1608_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1608_accel_watch.txt', index_col = False, header = None, names = cols)
data_1609_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1609_accel_watch.txt', index_col = False, header = None, names = cols)
data_1610_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1610_accel_watch.txt', index_col = False, header = None, names = cols)
data_1611_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1611_accel_watch.txt', index_col = False, header = None, names = cols)
data_1612_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1612_accel_watch.txt', index_col = False, header = None, names = cols)
data_1613_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1613_accel_watch.txt', index_col = False, header = None, names = cols)
data_1614_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1614_accel_watch.txt', index_col = False, header = None, names = cols)
data_1615_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1615_accel_watch.txt', index_col = False, header = None, names = cols)
data_1616_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1616_accel_watch.txt', index_col = False, header = None, names = cols)
data_1617_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1617_accel_watch.txt', index_col = False, header = None, names = cols)
data_1618_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1618_accel_watch.txt', index_col = False, header = None, names = cols)
data_1619_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1619_accel_watch.txt', index_col = False, header = None, names = cols)
data_1620_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1620_accel_watch.txt', index_col = False, header = None, names = cols)
data_1621_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1621_accel_watch.txt', index_col = False, header = None, names = cols)
data_1622_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1622_accel_watch.txt', index_col = False, header = None, names = cols)
data_1623_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1623_accel_watch.txt', index_col = False, header = None, names = cols)
data_1624_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1624_accel_watch.txt', index_col = False, header = None, names = cols)
data_1625_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1625_accel_watch.txt', index_col = False, header = None, names = cols)
data_1626_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1626_accel_watch.txt', index_col = False, header = None, names = cols)
data_1627_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1627_accel_watch.txt', index_col = False, header = None, names = cols)
data_1628_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1628_accel_watch.txt', index_col = False, header = None, names = cols)
data_1629_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1629_accel_watch.txt', index_col = False, header = None, names = cols)
data_1630_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1630_accel_watch.txt', index_col = False, header = None, names = cols)
data_1631_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1631_accel_watch.txt', index_col = False, header = None, names = cols)
data_1632_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1632_accel_watch.txt', index_col = False, header = None, names = cols)
data_1633_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1633_accel_watch.txt', index_col = False, header = None, names = cols)
data_1634_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1634_accel_watch.txt', index_col = False, header = None, names = cols)
data_1635_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1635_accel_watch.txt', index_col = False, header = None, names = cols)
data_1636_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1636_accel_watch.txt', index_col = False, header = None, names = cols)
data_1637_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1637_accel_watch.txt', index_col = False, header = None, names = cols)
data_1638_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1638_accel_watch.txt', index_col = False, header = None, names = cols)
data_1639_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1639_accel_watch.txt', index_col = False, header = None, names = cols)
data_1640_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1640_accel_watch.txt', index_col = False, header = None, names = cols)
data_1641_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1641_accel_watch.txt', index_col = False, header = None, names = cols)
data_1642_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1642_accel_watch.txt', index_col = False, header = None, names = cols)
data_1643_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1643_accel_watch.txt', index_col = False, header = None, names = cols)
data_1644_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1644_accel_watch.txt', index_col = False, header = None, names = cols)
data_1645_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1645_accel_watch.txt', index_col = False, header = None, names = cols)
data_1646_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1646_accel_watch.txt', index_col = False, header = None, names = cols)
data_1647_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1647_accel_watch.txt', index_col = False, header = None, names = cols)
data_1648_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1648_accel_watch.txt', index_col = False, header = None, names = cols)
data_1649_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1649_accel_watch.txt', index_col = False, header = None, names = cols)
data_1650_accel_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\accel\\data_1650_accel_watch.txt', index_col = False, header = None, names = cols)

# %% [markdown]
# # Reading Watch Gyroscope reading

# %%
data_1600_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1600_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1601_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1601_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1602_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1602_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1603_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1603_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1604_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1604_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1605_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1605_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1606_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1606_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1607_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1607_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1608_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1608_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1609_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1609_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1610_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1610_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1611_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1611_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1612_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1612_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1613_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1613_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1614_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1614_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1615_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1615_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1616_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1616_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1617_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1617_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1618_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1618_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1619_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1619_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1620_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1620_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1621_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1621_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1622_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1622_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1623_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1623_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1624_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1624_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1625_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1625_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1626_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1626_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1627_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1627_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1628_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1628_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1629_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1629_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1630_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1630_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1631_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1631_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1632_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1632_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1633_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1633_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1634_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1634_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1635_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1635_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1636_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1636_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1637_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1637_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1638_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1638_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1639_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1639_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1640_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1640_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1641_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1641_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1642_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1642_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1643_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1643_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1644_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1644_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1645_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1645_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1646_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1646_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1647_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1647_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1648_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1648_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1649_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1649_gyro_watch.txt', index_col = False, header = None, names = cols)
data_1650_gyro_watch = pd.read_csv('C:\\Users\\bimal\\Documents\\A-001 py programs\\Project\\phone and watch\\raw\\watch\\gyro\\data_1650_gyro_watch.txt', index_col = False, header = None, names = cols)

# %%
#data_1650_gyro_phone

# %% [raw]
# SUMMARY INFORMATION FOR THE DATASETS
#
# Number of subjects 51
# Number of activities 18
# Minutes collected per activity 3
# Sensor polling rate 20Hz
# Smartphone used Google Nexus 5/5x or
# Samsung Galaxy S5
# Smartwatch used LG G Watch
# Number raw measurements 15,630,426

# %% [raw]
# THE 18 ACTIVITIES REPRESENTED IN DATA SET
#
# Activity Code
# -------  -----
# Walking A
# Jogging B
# Stairs C
# Sitting D
# Standing E
# Typing F
# Brushing Teeth G
# Eating Soup H
# Eating Chips I
# Eating Pasta J
# Drinking from Cup K
# Eating Sandwich L
# Kicking (Soccer Ball) M
# Playing Catch w/Tennis Ball O
# Dribblinlg (Basketball) P
# Writing Q
# Clapping R
# Folding Clothes S

# %% [markdown]
# test.loc[test['activity_code']== 'A', 'activity_label'] = 'walking'
# test.loc[test['activity_code']== 'B', 'activity_label'] = 'jogging'
# test.loc[test['activity_code']== 'C', 'activity_label'] = 'stairs'
# test.loc[test['activity_code']== 'D', 'activity_label'] = 'sitting'
# test.loc[test['activity_code']== 'E', 'activity_label'] = 'stading'
# test.loc[test['activity_code']== 'F', 'activity_label'] = 'Typing'
# test.loc[test['activity_code']== 'G', 'activity_label'] = 'brushing teeth'
# test.loc[test['activity_code']== 'H', 'activity_label'] = 'eating soup'
# test.loc[test['activity_code']== 'I', 'activity_label'] = 'Eating chips'
# test.loc[test['activity_code']== 'J', 'activity_label'] = 'Eating pasta'
# test.loc[test['activity_code']== 'K', 'activity_label'] = 'drinking from cup'
# test.loc[test['activity_code']== 'L', 'activity_label'] = 'eating sandwich'
# test.loc[test['activity_code']== 'M', 'activity_label'] = 'kicking socer ball'
# test.loc[test['activity_code']== 'O', 'activity_label'] = 'playing catch w/tennis ball'
# test.loc[test['activity_code']== 'P', 'activity_label'] = 'dribbling basket ball'
# test.loc[test['activity_code']== 'Q', 'activity_label'] = 'writing'
# test.loc[test['activity_code']== 'R', 'activity_label'] = 'clapping'
# test.loc[test['activity_code']== 'S', 'activity_label'] = 'folding clothes'
#
# test

# %%
phone_accel = [data_1600_accel_phone, data_1601_accel_phone,data_1602_accel_phone, data_1603_accel_phone,data_1604_accel_phone,
          data_1605_accel_phone, data_1606_accel_phone,data_1607_accel_phone, data_1608_accel_phone,data_1609_accel_phone,
          data_1615_accel_phone, data_1616_accel_phone,data_1617_accel_phone, data_1618_accel_phone,data_1619_accel_phone,
          data_1610_accel_phone, data_1611_accel_phone,data_1612_accel_phone, data_1613_accel_phone,data_1614_accel_phone,
          data_1620_accel_phone, data_1621_accel_phone,data_1622_accel_phone, data_1623_accel_phone,data_1624_accel_phone,
          data_1625_accel_phone, data_1626_accel_phone,data_1627_accel_phone, data_1628_accel_phone,data_1629_accel_phone,
          data_1630_accel_phone, data_1631_accel_phone,data_1632_accel_phone, data_1633_accel_phone,data_1634_accel_phone,
          data_1635_accel_phone, data_1636_accel_phone,data_1637_accel_phone, data_1638_accel_phone,data_1639_accel_phone,
          data_1640_accel_phone, data_1641_accel_phone,data_1642_accel_phone, data_1643_accel_phone,data_1644_accel_phone,
          data_1645_accel_phone, data_1646_accel_phone,data_1647_accel_phone, data_1648_accel_phone,data_1649_accel_phone,
          data_1650_accel_phone, ]
phone_accel_df = pd.DataFrame()
phone_accel_df= phone_accel_df.append(phone_accel, ignore_index = False)

# %%
phone_gyro = [data_1600_gyro_phone, data_1601_gyro_phone,data_1602_gyro_phone, data_1603_gyro_phone,data_1604_gyro_phone,
          data_1605_gyro_phone, data_1606_gyro_phone,data_1607_gyro_phone, data_1608_gyro_phone,data_1609_gyro_phone,
          data_1615_gyro_phone, data_1616_gyro_phone,data_1617_gyro_phone, data_1618_gyro_phone,data_1619_gyro_phone,
          data_1610_gyro_phone, data_1611_gyro_phone,data_1612_gyro_phone, data_1613_gyro_phone,data_1614_gyro_phone,
          data_1620_gyro_phone, data_1621_gyro_phone,data_1622_gyro_phone, data_1623_gyro_phone,data_1624_gyro_phone,
          data_1625_gyro_phone, data_1626_gyro_phone,data_1627_gyro_phone, data_1628_gyro_phone,data_1629_gyro_phone,
          data_1630_gyro_phone, data_1631_gyro_phone,data_1632_gyro_phone, data_1633_gyro_phone,data_1634_gyro_phone,
          data_1635_gyro_phone, data_1636_gyro_phone,data_1637_gyro_phone, data_1638_gyro_phone,data_1639_gyro_phone,
          data_1640_gyro_phone, data_1641_gyro_phone,data_1642_gyro_phone, data_1643_gyro_phone,data_1644_gyro_phone,
          data_1645_gyro_phone, data_1646_gyro_phone,data_1647_gyro_phone, data_1648_gyro_phone,data_1649_gyro_phone,
          data_1650_gyro_phone]
phone_gyro_df = pd.DataFrame()
phone_gyro_df = phone_gyro_df.append(phone_gyro, ignore_index = False)

# %%
watch_accel = [data_1600_accel_watch, data_1601_accel_watch,data_1602_accel_watch, data_1603_accel_watch,data_1604_accel_watch,
          data_1605_accel_watch, data_1606_accel_watch,data_1607_accel_watch, data_1608_accel_watch,data_1609_accel_watch,
          data_1615_accel_watch, data_1616_accel_watch,data_1617_accel_watch, data_1618_accel_watch,data_1619_accel_watch,
          data_1610_accel_watch, data_1611_accel_watch,data_1612_accel_watch, data_1613_accel_watch,data_1614_accel_watch,
          data_1620_accel_watch, data_1621_accel_watch,data_1622_accel_watch, data_1623_accel_watch,data_1624_accel_watch,
          data_1625_accel_watch, data_1626_accel_watch,data_1627_accel_watch, data_1628_accel_watch,data_1629_accel_watch,
          data_1630_accel_watch, data_1631_accel_watch,data_1632_accel_watch, data_1633_accel_watch,data_1634_accel_watch,
          data_1635_accel_watch, data_1636_accel_watch,data_1637_accel_watch, data_1638_accel_watch,data_1639_accel_watch,
          data_1640_accel_watch, data_1641_accel_watch,data_1642_accel_watch, data_1643_accel_watch,data_1644_accel_watch,
          data_1645_accel_watch, data_1646_accel_watch,data_1647_accel_watch, data_1648_accel_watch,data_1649_accel_watch,
          data_1650_accel_watch]
watch_accel_df = pd.DataFrame()
watch_accel_df = watch_accel_df.append(watch_accel, ignore_index = False)

# %%
watch_gyro =[data_1600_gyro_watch, data_1601_gyro_watch,data_1602_gyro_watch, data_1603_gyro_watch,data_1604_gyro_watch,
          data_1605_gyro_watch, data_1606_gyro_watch,data_1607_gyro_watch, data_1608_gyro_watch,data_1609_gyro_watch,
          data_1615_gyro_watch, data_1616_gyro_watch,data_1617_gyro_watch, data_1618_gyro_watch,data_1619_gyro_watch,
          data_1610_gyro_watch, data_1611_gyro_watch,data_1612_gyro_watch, data_1613_gyro_watch,data_1614_gyro_watch,
          data_1620_gyro_watch, data_1621_gyro_watch,data_1622_gyro_watch, data_1623_gyro_watch,data_1624_gyro_watch,
          data_1625_gyro_watch, data_1626_gyro_watch,data_1627_gyro_watch, data_1628_gyro_watch,data_1629_gyro_watch,
          data_1630_gyro_watch, data_1631_gyro_watch,data_1632_gyro_watch, data_1633_gyro_watch,data_1634_gyro_watch,
          data_1635_gyro_watch, data_1636_gyro_watch,data_1637_gyro_watch, data_1638_gyro_watch,data_1639_gyro_watch,
          data_1640_gyro_watch, data_1641_gyro_watch,data_1642_gyro_watch, data_1643_gyro_watch,data_1644_gyro_watch,
          data_1645_gyro_watch, data_1646_gyro_watch,data_1647_gyro_watch, data_1648_gyro_watch,data_1649_gyro_watch,
          data_1650_gyro_watch]

watch_gyro_df = pd.DataFrame()
watch_gyro_df = watch_gyro_df.append(watch_gyro, ignore_index = False)

# %%
phone_accel_df['heading'] = 'phone accel'
phone_gyro_df['heading'] = 'phone gyro'
watch_accel_df['heading'] = 'watch accel'
watch_gyro_df['heading'] = 'watch gyro'

# %%
test = phone_accel_df
test.loc[test['activity_code']== 'A', 'activity_label'] = 'walking'
test.loc[test['activity_code']== 'B', 'activity_label'] = 'jogging'
test.loc[test['activity_code']== 'C', 'activity_label'] = 'stairs'
test.loc[test['activity_code']== 'D', 'activity_label'] = 'sitting'
test.loc[test['activity_code']== 'E', 'activity_label'] = 'stading'
test.loc[test['activity_code']== 'F', 'activity_label'] = 'Typing'
test.loc[test['activity_code']== 'G', 'activity_label'] = 'brushing teeth'
test.loc[test['activity_code']== 'H', 'activity_label'] = 'eating soup'
test.loc[test['activity_code']== 'I', 'activity_label'] = 'eating chips'
test.loc[test['activity_code']== 'J', 'activity_label'] = 'eating pasta'
test.loc[test['activity_code']== 'K', 'activity_label'] = 'drinking from cup'
test.loc[test['activity_code']== 'L', 'activity_label'] = 'eating sandwich'
test.loc[test['activity_code']== 'M', 'activity_label'] = 'kicking socer ball'
test.loc[test['activity_code']== 'O', 'activity_label'] = 'playing catch w/tennis ball'
test.loc[test['activity_code']== 'P', 'activity_label'] = 'dribbling basket ball'
test.loc[test['activity_code']== 'Q', 'activity_label'] = 'writing'
test.loc[test['activity_code']== 'R', 'activity_label'] = 'clapping'
test.loc[test['activity_code']== 'S', 'activity_label'] = 'folding clothes'
phone_accel_df = test

# %%
test = phone_gyro_df
test.loc[test['activity_code']== 'A', 'activity_label'] = 'walking'
test.loc[test['activity_code']== 'B', 'activity_label'] = 'jogging'
test.loc[test['activity_code']== 'C', 'activity_label'] = 'stairs'
test.loc[test['activity_code']== 'D', 'activity_label'] = 'sitting'
test.loc[test['activity_code']== 'E', 'activity_label'] = 'stading'
test.loc[test['activity_code']== 'F', 'activity_label'] = 'Typing'
test.loc[test['activity_code']== 'G', 'activity_label'] = 'brushing teeth'
test.loc[test['activity_code']== 'H', 'activity_label'] = 'eating soup'
test.loc[test['activity_code']== 'I', 'activity_label'] = 'eating chips'
test.loc[test['activity_code']== 'J', 'activity_label'] = 'eating pasta'
test.loc[test['activity_code']== 'K', 'activity_label'] = 'drinking from cup'
test.loc[test['activity_code']== 'L', 'activity_label'] = 'eating sandwich'
test.loc[test['activity_code']== 'M', 'activity_label'] = 'kicking socer ball'
test.loc[test['activity_code']== 'O', 'activity_label'] = 'playing catch w/tennis ball'
test.loc[test['activity_code']== 'P', 'activity_label'] = 'dribbling basket ball'
test.loc[test['activity_code']== 'Q', 'activity_label'] = 'writing'
test.loc[test['activity_code']== 'R', 'activity_label'] = 'clapping'
test.loc[test['activity_code']== 'S', 'activity_label'] = 'folding clothes'
phone_gyro_df = test

# %%
test = watch_gyro_df
test.loc[test['activity_code']== 'A', 'activity_label'] = 'walking'
test.loc[test['activity_code']== 'B', 'activity_label'] = 'jogging'
test.loc[test['activity_code']== 'C', 'activity_label'] = 'stairs'
test.loc[test['activity_code']== 'D', 'activity_label'] = 'sitting'
test.loc[test['activity_code']== 'E', 'activity_label'] = 'stading'
test.loc[test['activity_code']== 'F', 'activity_label'] = 'Typing'
test.loc[test['activity_code']== 'G', 'activity_label'] = 'brushing teeth'
test.loc[test['activity_code']== 'H', 'activity_label'] = 'eating soup'
test.loc[test['activity_code']== 'I', 'activity_label'] = 'eating chips'
test.loc[test['activity_code']== 'J', 'activity_label'] = 'eating pasta'
test.loc[test['activity_code']== 'K', 'activity_label'] = 'drinking from cup'
test.loc[test['activity_code']== 'L', 'activity_label'] = 'eating sandwich'
test.loc[test['activity_code']== 'M', 'activity_label'] = 'kicking socer ball'
test.loc[test['activity_code']== 'O', 'activity_label'] = 'playing catch w/tennis ball'
test.loc[test['activity_code']== 'P', 'activity_label'] = 'dribbling basket ball'
test.loc[test['activity_code']== 'Q', 'activity_label'] = 'writing'
test.loc[test['activity_code']== 'R', 'activity_label'] = 'clapping'
test.loc[test['activity_code']== 'S', 'activity_label'] = 'folding clothes'
watch_gyro_df = test

# %%
test = watch_accel_df
test.loc[test['activity_code']== 'A', 'activity_label'] = 'walking'
test.loc[test['activity_code']== 'B', 'activity_label'] = 'jogging'
test.loc[test['activity_code']== 'C', 'activity_label'] = 'stairs'
test.loc[test['activity_code']== 'D', 'activity_label'] = 'sitting'
test.loc[test['activity_code']== 'E', 'activity_label'] = 'stading'
test.loc[test['activity_code']== 'F', 'activity_label'] = 'Typing'
test.loc[test['activity_code']== 'G', 'activity_label'] = 'brushing teeth'
test.loc[test['activity_code']== 'H', 'activity_label'] = 'eating soup'
test.loc[test['activity_code']== 'I', 'activity_label'] = 'eating chips'
test.loc[test['activity_code']== 'J', 'activity_label'] = 'eating pasta'
test.loc[test['activity_code']== 'K', 'activity_label'] = 'drinking from cup'
test.loc[test['activity_code']== 'L', 'activity_label'] = 'eating sandwich'
test.loc[test['activity_code']== 'M', 'activity_label'] = 'kicking socer ball'
test.loc[test['activity_code']== 'O', 'activity_label'] = 'playing catch w/tennis ball'
test.loc[test['activity_code']== 'P', 'activity_label'] = 'dribbling basket ball'
test.loc[test['activity_code']== 'Q', 'activity_label'] = 'writing'
test.loc[test['activity_code']== 'R', 'activity_label'] = 'clapping'
test.loc[test['activity_code']== 'S', 'activity_label'] = 'folding clothes'
watch_accel_df = test

# %%
watch_accel_df.sample(5)
# Out:
#        sub_id activity_code         timestamp          x         y  \
# 31059    1623             I    12492132020097  -6.225523 -6.168361
# 16034    1609             E   852854883212415   5.241656  1.256657
# 56442    1622             Q   203828147385615   0.622492  9.671378
# 146      1626             A   372832065544010  12.095656 -2.661305
# 24456    1644             G  1818443218702470  -9.859023 -0.413149
#
#                  z      heading  activity_label
# 31059    2.585289;  watch accel    eating chips
# 16034   -8.218247;  watch accel         stading
# 56442   1.4662989;  watch accel         writing
# 146    -1.9185038;  watch accel         walking
# 24456   0.3417723;  watch accel  brushing teeth

# %%
watch_gyro_df.sample(5)
# Out:
#        sub_id activity_code        timestamp         x         y  \
# 14628    1616             F  107790835674153  0.046787 -0.043651
# 3786     1626             B  373063105824241  3.885288 -2.844430
# 51049    1634             P   84358161388170  3.204957 -0.567503
# 55853    1612             Q    8269088512135  0.120133  0.040287
# 6385     1608             B  790078464058535 -0.397814 -0.021919
#
#                     z     heading         activity_label
# 14628   -0.013687316;  watch gyro                 Typing
# 3786       1.8981782;  watch gyro                jogging
# 51049      0.5629584;  watch gyro  dribbling basket ball
# 55853  -0.0075497953;  watch gyro                writing
# 6385      -1.1624035;  watch gyro                jogging

# %%
phone_gyro_df.sample(5)
# Out:
#        sub_id activity_code        timestamp         x         y  \
# 7003     1650             B  359953507834000  0.533698  0.787230
# 7315     1640             C  172223239141366  0.587654 -0.517057
# 33067    1611             J    1712496119426 -0.003174 -0.001251
# 18296    1635             F  679679174499642 -0.027695  0.002914
# 64348    1613             P  178008350817501 -0.097738 -1.186705
#
#                   z     heading         activity_label
# 7003    0.18002969;  phone gyro                jogging
# 7315    0.20134057;  phone gyro                 stairs
# 33067  0.006652832;  phone gyro           eating pasta
# 18296  -0.03691101;  phone gyro                 Typing
# 64348   -0.5203817;  phone gyro  dribbling basket ball

# %%
phone_accel_df.sample(5)
# Out:
#         sub_id activity_code         timestamp         x         y  \
# 53641     1642             I  1470236846904000 -3.305127  4.366121
# 61441     1620             J   941418629139022 -0.836197  9.767151
# 114308    1648             M   460679989846000 -2.725532 -5.369634
# 61669     1637             S    13300951550394 -9.078513 -5.336226
# 83810     1616             P   193482307929788  6.555603 -5.300384
#
#                   z      heading         activity_label
# 53641     8.825647;  phone accel           eating chips
# 61441   -1.0289459;  phone accel           eating pasta
# 114308  -1.6286134;  phone accel     kicking socer ball
# 61669    7.6940665;  phone accel        folding clothes
# 83810    2.9267883;  phone accel  dribbling basket ball

# %%
phone_accel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4804403 entries, 0 to 160778
# Data columns (total 8 columns):
# sub_id            int64
# activity_code     object
# timestamp         int64
# x                 float64
# y                 float64
# z                 object
# heading           object
# activity_label    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 329.9+ MB

# %%
phone_merge = [phone_gyro_df,phone_accel_df ,watch_gyro_df,watch_accel_df  ]

# %%
wisdm = pd.concat( phone_merge)

# %%
wisdm.sample(15)
# Out:
#        sub_id activity_code         timestamp         x         y  \
# 2356     1603             A     8578765296785 -0.452205  3.503921
# 62282    1625             I   708842609417661 -8.051529 -0.744995
# 49094    1613             O   616273086605551  2.421001  0.858300
# 28886    1624             I   291931142742289  0.285898  0.202525
# 16001    1614             E    84401494288122  8.409933 -4.705055
# 18442    1613             E   174602483811330  0.012517  0.054328
# 62944    1630             S  1558350954900837  0.117371 -0.082153
# 40306    1633             I   693020234693547  0.521591 -9.662613
# 33230    1623             J    12953354515470 -2.063652 -6.449231
# 39698    1613             I   176619225141432 -0.013049 -0.012783
# 62623    1637             S    13348625867704  2.363376 -6.626701
# 29965    1611             I     3839658482345 -7.054964  0.919373
# 11486    1625             D   479177036863427  0.286556 -2.217330
# ...

# %% [raw]
# # import pandas_profiling
#
# profile = pandas_profiling.ProfileReport(wisdm)
# profile.to_file('Wisdm.html')

# %%
wisdm.to_csv('wisdm.csv')

# %%
print('done')
# Out:
# done

# %%
wisdm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15630426 entries, 0 to 66591
# Data columns (total 8 columns):
# sub_id            int64
# activity_code     object
# timestamp         int64
# x                 float64
# y                 float64
# z                 object
# heading           object
# activity_label    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.0+ GB

# %%
testcsv = pd.read_csv('wisdm.csv', chunksize =)

# %%
wisdm.head()
# Out:
#    sub_id activity_code        timestamp         x         y             z  \
# 0    1600             A  252207918580802 -0.853210  0.297226    0.8901825;
# 1    1600             A  252207968934806 -0.875137  0.015472   0.16223145;
# 2    1600             A  252208019288809 -0.720169  0.388489  -0.28401184;
# 3    1600             A  252208069642813 -0.571640  1.227402   -0.2416687;
# 4    1600             A  252208119996817 -0.380493  1.202835  -0.21313477;
#
#       heading activity_label
# 0  phone gyro        walking
# 1  phone gyro        walking
# 2  phone gyro        walking
# 3  phone gyro        walking
# 4  phone gyro        walking

# %%
wisdm.drop('activity_code',axis = 1, inplace = True ) # removing column to get free space

# %%
wisdm.drop('timestamp',axis = 1, inplace = True )  # removing column to get free space

# %%
wisdm.head()
# Out:
#    sub_id         x         y             z     heading activity_label
# 0    1600 -0.853210  0.297226    0.8901825;  phone gyro        walking
# 1    1600 -0.875137  0.015472   0.16223145;  phone gyro        walking
# 2    1600 -0.720169  0.388489  -0.28401184;  phone gyro        walking
# 3    1600 -0.571640  1.227402   -0.2416687;  phone gyro        walking
# 4    1600 -0.380493  1.202835  -0.21313477;  phone gyro        walking

# %%
wisdm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15630426 entries, 0 to 66591
# Data columns (total 6 columns):
# sub_id            int64
# x                 float64
# y                 float64
# z                 object
# heading           object
# activity_label    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 834.8+ MB

# %%
wisdm.to_csv('wisdm_ok.csv')

# %%
print(done)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-f30aa95cabce> in <module>
# ----> 1 print(done)
#
# NameError: name 'done' is not defined

# %%
test_wisdm = pd.read_csv('wisdm_ok.csv')

# %%
print('done')
# Out:
# done

# %%
wisdm_data = test_wisdm

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-3fa9da75515f> in <module>
# ----> 1 wisdm_data.groupby('heading').plot().bar()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'bar'
