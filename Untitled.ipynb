# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('wisdm_ok.csv')
data0= pd.read_csv('wisdm.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15630426 entries, 0 to 15630425
# Data columns (total 7 columns):
# Unnamed: 0        int64
# sub_id            int64
# x                 float64
# y                 float64
# z                 object
# heading           object
# activity_label    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 834.8+ MB

# %%
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15630426 entries, 0 to 15630425
# Data columns (total 9 columns):
# Unnamed: 0        int64
# sub_id            int64
# activity_code     object
# timestamp         int64
# x                 float64
# y                 float64
# z                 float64
# heading           object
# activity_label    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.0+ GB

# %%
data.head()
# Out:
#    Unnamed: 0  sub_id         x         y             z     heading  \
# 0           0    1600 -0.853210  0.297226    0.8901825;  phone gyro
# 1           1    1600 -0.875137  0.015472   0.16223145;  phone gyro
# 2           2    1600 -0.720169  0.388489  -0.28401184;  phone gyro
# 3           3    1600 -0.571640  1.227402   -0.2416687;  phone gyro
# 4           4    1600 -0.380493  1.202835  -0.21313477;  phone gyro
#
#   activity_label
# 0        walking
# 1        walking
# 2        walking
# 3        walking
# 4        walking

# %%
data0.head()
# Out:
#    Unnamed: 0  sub_id activity_code        timestamp         x         y  \
# 0           0    1600             A  252207918580802 -0.853210  0.297226
# 1           1    1600             A  252207968934806 -0.875137  0.015472
# 2           2    1600             A  252208019288809 -0.720169  0.388489
# 3           3    1600             A  252208069642813 -0.571640  1.227402
# 4           4    1600             A  252208119996817 -0.380493  1.202835
#
#               z     heading activity_label
# 0    0.8901825;  phone gyro        walking
# 1   0.16223145;  phone gyro        walking
# 2  -0.28401184;  phone gyro        walking
# 3   -0.2416687;  phone gyro        walking
# 4  -0.21313477;  phone gyro        walking

# %%
data.z =data.z.str.strip(';')
data0.z = data0.z.str.strip(';')
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-528b10cd0641> in <module>
# ----> 1 data.z =data.z.str.strip(';')
#       2 data0.z = data0.z.str.strip(';')
#       3 data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
# ...

# %%
data.z = data.z.astype(float)
data0.z = data0.z.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15630426 entries, 0 to 15630425
# Data columns (total 7 columns):
# Unnamed: 0        int64
# sub_id            int64
# x                 float64
# y                 float64
# z                 float64
# heading           object
# activity_label    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 834.8+ MB

# %%
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15630426 entries, 0 to 15630425
# Data columns (total 9 columns):
# Unnamed: 0        int64
# sub_id            int64
# activity_code     object
# timestamp         int64
# x                 float64
# y                 float64
# z                 float64
# heading           object
# activity_label    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.0+ GB

# %%
pwalk = data[(data['activity_label']== 'walking') & (data['heading'] == 'phone gyro')][:]
wwalk = data[(data['activity_label']== 'walking') & (data['heading'] == 'watch gyro')][:]


pjog = data0[(data0['activity_label']== 'jogging') & (data['heading'] == 'phone gyro')][:]
wjog = data0[(data0['activity_label']== 'jogging') & (data['heading'] == 'watch gyro')][:]

# %%
pjog.head()
# Out:
#       Unnamed: 0  sub_id activity_code        timestamp         x         y  \
# 3569        3569    1600             B  251987770883934  0.410278  1.710571
# 3570        3570    1600             B  251987821237937 -0.256134  0.380859
# 3571        3571    1600             B  251987871591941 -0.691132 -0.299866
# 3572        3572    1600             B  251987921945945  0.525040 -0.006882
# 3573        3573    1600             B  251987972299949 -1.007584 -0.192322
#
#              z     heading activity_label
# 3569  0.504745  phone gyro        jogging
# 3570 -0.295776  phone gyro        jogging
# 3571  0.030258  phone gyro        jogging
# 3572  0.728622  phone gyro        jogging
# 3573 -1.147400  phone gyro        jogging

# %%
pjog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200252 entries, 3569 to 3537214
# Data columns (total 3 columns):
# x    200252 non-null float64
# y    200252 non-null float64
# z    200252 non-null float64
# dtypes: float64(3)
# memory usage: 11.1 MB

# %%
dropper = ['Unnamed: 0', 'sub_id', 'activity_code', 'timestamp','heading', 'activity_label']
#pjog.drop(dropper, axis = 1, inplace = True)
#wjog.drop(dropper, axis = 1, inplace = True)

# %%
wjog.head()

print('length of pjog is {} and lenght of wjog is {}'.format(len(pjog), len(wjog)))
# Out:
# length of pjog is 200252 and lenght of wjog is 187833

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df = pd.DataFrame()

# %%
df1 = pd.DataFrame({'sr' : range(1, len(pwalk)+1),
                   'pwx': pwalk.x,
                  'pwy': pwalk.y,
                  'pwz': pwalk.z
            })
df2 = pd.DataFrame({'sr' : range(1, len(pjog)+1),
                    'pjx': pjog.x,
                  'pjy': pjog.y,
                  'pjz': pjog.z
             })
df3 = pd.DataFrame({'sr' : range(1, len(wwalk)+1),
                    'wwx': wwalk.x,
                  'wwy': wwalk.y,
                  'wwz': wwalk.z
           })
df4 = pd.DataFrame({'sr' : range(1, len(wjog)+1),
                    'wjx': wjog.x,
                  'wjy': wjog.y,
                  'wjz': wjog.z                   
                  })
df = pd.DataFrame({'sr' : range(1, (len(pwalk)+len(pjog) +len(wwalk)+len(wjog)+1)),
                  'pwx': pwalk.x,
                  'pwy': pwalk.y,
                  'pwz': pwalk.z,
                  'pjx': pjog.x,
                  'pjy': pjog.y,
                  'pjz': pjog.z,
                  'wwx': wwalk.x,
                  'wwy': wwalk.y,
                  'wwz': wwalk.z,
                  'wjx': wjog.x,
                  'wjy': wjog.y,
                  'wjz': wjog.z  
      })

# %%
df1.head()
# Out:
#    sr       pwx       pwy       pwz
# 0   1 -0.853210  0.297226  0.890182
# 1   2 -0.875137  0.015472  0.162231
# 2   3 -0.720169  0.388489 -0.284012
# 3   4 -0.571640  1.227402 -0.241669
# 4   5 -0.380493  1.202835 -0.213135

# %%
df2.head()
# Out:
#       sr       pjx       pjy       pjz
# 3569   1  0.410278  1.710571  0.504745
# 3570   2 -0.256134  0.380859 -0.295776
# 3571   3 -0.691132 -0.299866  0.030258
# 3572   4  0.525040 -0.006882  0.728622
# 3573   5 -1.007584 -0.192322 -1.147400

# %%
df_merged = df1.merge(df2, on = 'sr', how= 'outer')
df_merged = df_merged.merge(df3, on = 'sr', how = 'outer')
df_merged = df_merged.merge(df4, on = 'sr', how = 'outer')
df_merged.head()
# Out:
#    sr       pwx       pwy       pwz       pjx       pjy       pjz       wwx  \
# 0   1 -0.853210  0.297226  0.890182  0.410278  1.710571  0.504745  0.314944
# 1   2 -0.875137  0.015472  0.162231 -0.256134  0.380859 -0.295776  0.387382
# 2   3 -0.720169  0.388489 -0.284012 -0.691132 -0.299866  0.030258  0.070999
# 3   4 -0.571640  1.227402 -0.241669  0.525040 -0.006882  0.728622  0.037975
# 4   5 -0.380493  1.202835 -0.213135 -1.007584 -0.192322 -1.147400  0.073129
#
#         wwy       wwz       wjx       wjy       wjz
# 0 -1.022277 -0.309962  1.474375  2.161206 -3.551682
# 1 -0.618541 -0.048972 -0.820205  2.115400 -4.279257
# 2 -0.209480 -0.195978 -0.276920  1.225904 -0.768146
# 3  0.254976 -0.156563  1.989963  0.423760 -0.290907
# 4  0.719431 -0.001035  2.147622  0.233078  0.080870

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203919 entries, 0 to 203918
# Data columns (total 13 columns):
# sr     203919 non-null int64
# pwx    203919 non-null float64
# pwy    203919 non-null float64
# pwz    203919 non-null float64
# pjx    200252 non-null float64
# pjy    200252 non-null float64
# pjz    200252 non-null float64
# wwx    192531 non-null float64
# wwy    192531 non-null float64
# wwz    192531 non-null float64
# wjx    187833 non-null float64
# wjy    187833 non-null float64
# wjz    187833 non-null float64
# dtypes: float64(12), int64(1)
# memory usage: 21.8 MB

# %%
df_values_only = df_merged.drop('sr', axis = 1)
df_values_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203919 entries, 0 to 203918
# Data columns (total 12 columns):
# pwx    203919 non-null float64
# pwy    203919 non-null float64
# pwz    203919 non-null float64
# pjx    200252 non-null float64
# pjy    200252 non-null float64
# pjz    200252 non-null float64
# wwx    192531 non-null float64
# wwy    192531 non-null float64
# wwz    192531 non-null float64
# wjx    187833 non-null float64
# wjy    187833 non-null float64
# wjz    187833 non-null float64
# dtypes: float64(12)
# memory usage: 20.2 MB

# %%
ph_walk_jog = pd.merge(df1, df2, on = 'sr', how = 'outer')
ph_walk_jog = ph_walk_jog.drop('sr', axis = 1)

# %%
ph_walk_jog.head()
# Out:
#         pwx       pwy       pwz       pjx       pjy       pjz
# 0 -0.853210  0.297226  0.890182  0.410278  1.710571  0.504745
# 1 -0.875137  0.015472  0.162231 -0.256134  0.380859 -0.295776
# 2 -0.720169  0.388489 -0.284012 -0.691132 -0.299866  0.030258
# 3 -0.571640  1.227402 -0.241669  0.525040 -0.006882  0.728622
# 4 -0.380493  1.202835 -0.213135 -1.007584 -0.192322 -1.147400

# %%
sns.pairplot(ph_walk_jog )
# Out:
# C:\Users\bimal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\bimal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.lmplot(data = ph_walk_jog, x = 'pwz', y = 'pjz')

# %%
sns.pairplot(df_values_only)
# Out:
# Error in callback <function flush_figures at 0x0000022482C201F8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...
